# %%
from google.colab import files
import os
import shutil

# Upload files
uploaded = files.upload()

# Create a static directory if it doesn't exist
if not os.path.exists('static'):
    os.makedirs('static')

# Move uploaded files to the static directory
for filename in uploaded.keys():
    shutil.move(filename, 'static/' + filename)
# Out:
#      <input type="file" id="files-9f6bcb7c-683f-4cc1-a70b-bec4519df2ed" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9f6bcb7c-683f-4cc1-a70b-bec4519df2ed">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !pip install flask tensorflow pillow flask-ngrok pandas scikit-learn pyngrok
import shutil
from google.colab import files
import os
import shutil
from flask import Flask, request, jsonify, render_template_string
from pyngrok import ngrok
from sklearn.experimental import enable_hist_gradient_boosting  # Needed to use HistGradientBoostingClassifier
from sklearn.ensemble import HistGradientBoostingClassifier
from sklearn.impute import SimpleImputer
import joblib
import pandas as pd
import numpy as np
from pyngrok import ngrok
from sklearn.pipeline import Pipeline

# Initialize Flask app

# Initialize Flask app
app = Flask(__name__, static_url_path='/static', static_folder='static')
#app = Flask(__name__, static_folder='/content/static')
imputer = SimpleImputer(strategy='mean')
model = joblib.load('model.joblib')
imputer = joblib.load('/content/imputer.joblib')
@app.route('/')
def index():
    return render_template_string('''
    <!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>House Price Prediction</title>
</head>
<style>
    /* Your CSS goes here */
body {
font-family: Arial, sans-serif;
margin: 0;
padding: 0;
}

.top-block {
background-color: #dff179; /* Light gray background */
padding: 100px;
text-align: center;
display: center;
align-items: center;
}

.top-block h1 {
color: #0f1010;
font-size: 36px; /* Larger font size */
margin: 0;
}
.top-block p {
color: #0c0d0d;
font-size: 36px; /* Larger font size */
margin: 0;
}
.image-container {
display: flex;
justify-content: center;
gap: 20px;
flex: 1;
}

.image-container img {
max-width: 50%;
height: auto;
box-shadow: none;
border-radius: 8px;

}
.image-containers {
display: flex;
justify-content: center;
gap: 20px;
flex: 1;
}

.image-containers img {
max-width: 90%;
height: auto;
box-shadow: none;
border-radius: 8px;

}
img {
border-radius: 50%;
}
button {
background-color: #dad849; /* Green */
border: none;
color: white;
padding: 16px 32px;
text-align: center;
text-decoration: none;
display: inline-block;
font-size: 16px;
margin: 4px 2px;
transition-duration: 0.4s;
cursor: pointer;
}
.button2:hover {
background-color: #d8d77b;
color: white;
}
.bottom-block {
background-color: #f1ff9f; /* Blue background */
padding: 20px;
color: rgb(179, 165, 159);
background-attachment: fixed;
}


.middle-block {
background-color: #ddec96; /* Blue background */
padding: 20px;
color: rgb(21, 22, 22);
background-attachment: fixed;
}
.inputs-section {
display: flex;
justify-content: center;
align-items: center;
gap: 20px;
}

.left-image-container {
flex: 1;
}

.left-image-container img {
max-width: 100%;
height: auto;
box-shadow: none;
border-radius: 8px;
}

.inputs {
flex: 1;
display: flex;
flex-direction: column;
align-items: center;
}

.input-group {
margin: 10px 0;
width: 100%;
max-width: 300px;
}

.input-group label {
display: block;
margin-bottom: 5px;
transition: color 0.3s ease;
}

.input-group input {
width: 100%;
padding: 10px;
border: 1px solid #dcd906;
border-radius: 4px;
background-color: #d1d3c5;
color: #060606;
transition: border-color 0.3s ease;
}

.input-group input:focus {
border-color: #97a7b7;
outline: none;
}

.input-group label:hover {
color: #3cc712;
}
.center {
text-align: center;
border: 3px solid rgb(98, 170, 88);
}


</style>

<body>
    <div class="top-block">
        <h1>Home Price Predictor</h1>
        <div class="image-container">
            <img src="/static/Capture d'écran 2024-07-21 160325.png" alt="Image 1" id="image1">
            <img src="/static/Capture d'écran 2024-07-21 160410.png" alt="Image 2" id="image2">
        </div>
    </div>

    <div class="middle-block">

        <div class="inputs-section">

            <div class="inputs">
                <p>Fill in the details below to analyze house price prediction.</p>
                <div class="input-group">
                    <label for="input1">area:</label>
                    <input type="text" id="input1">
                </div>
                <div class="input-group">
                    <label for="input2">bedrooms:</label>
                    <input type="text" id="input2">
                </div>
                <div class="input-group">
                    <label for="input3">bathrooms:</label>
                    <input type="text" id="input3">
                </div>
                <div class="input-group">
                    <label for="input4">stories:</label>
                    <input type="text" id="input4">
                </div>
                <div class="input-group">
                    <label for="input5">mainroad:</label>
                    <input type="text" id="input5">
                </div>
                <div class="input-group">
                    <label for="input6">guestroom:</label>
                    <input type="text" id="input6">
                </div>
                <div class="input-group">
                    <label for="input7">basement:</label>
                    <input type="text" id="input7">
                </div>
                <div class="input-group">
                    <label for="input8">hotwaterheating:</label>
                    <input type="text" id="input8">
                </div>
                <div class="input-group">
                    <label for="input9">airconditioning:</label>
                    <input type="text" id="input9">
                </div>
                <div class="input-group">
                    <label for="input10">parking:</label>
                    <input type="text" id="input10">
                </div>
                <div class="input-group">
                    <label for="input11">prefarea:</label>
                    <input type="text" id="input11">
                </div>
                <div class="input-group">
                    <label for="input12">furnishingstatus:</label>
                    <input type="text" id="input12">
                </div>
                <div> <button id="submit" class="button button2">Predict</button></div>
                <h2 id="prediction">Prediction: </h2>
                </div>
            </div>

        </div>

    </div>

    <div class="bottom-block">

            <div class="image-containers">
                <img src="/static/xxxx.png" alt="Image 1" id="image1">
        </div>
    </div>
    </div>
    <script>
        document.getElementById('submit').onclick = async function() {
            const inputs = {};
            for (let i = 1; i <= 12; i++) {
                inputs['input' + i] = document.getElementById('input' + i).value;
            }

            const response = await fetch('/predict', {
                method: 'POST',
                headers: {
                    'Content-Type': 'application/json'
                },
                body: JSON.stringify(inputs)
            });

            const result = await response.json();
            if (result.prediction !== undefined) {
                document.getElementById('prediction').innerText = 'Prediction: ' + result.prediction;
            } else {
                document.getElementById('prediction').innerText = 'Error: ' + result.error;
            }
        };
    </script>
</body>
</html>
''')

# %%
@app.route('/predict', methods=['POST'])
def predict():

        df = request.json
        print("Received data:", df)
        features =[ 'area', 'bedrooms', 'bathrooms', 'stories', 'mainroad',
       'guestroom', 'basement', 'hotwaterheating', 'airconditioning',
       'parking', 'prefarea', 'furnishingstatus']

        df1 = pd.DataFrame([df])
        print("Input data before imputation:", df1)

        # Convert input data to a DataFrame
        input_data = pd.DataFrame([df], columns=features)
        print("Input data before imputation:", input_data)

        # Replace empty strings with NaN
        df1.replace("", np.nan, inplace=True)
        print("Input data after replacing empty strings with NaN:", df1)

        # Impute missing values
        imputer = SimpleImputer(strategy='mean')
        imputed_data = imputer.fit_transform(df1)
        print("Input data after imputation:", imputed_data)
          # Ensure the input is correct
        if imputed_data.shape[1] == 12:
        # Make prediction
          prediction = model.predict(imputed_data)
          prediction = prediction[0].item()  # Convert numpy type to native Python type
          return jsonify({'prediction': prediction})
        else:
          return jsonify({'error': 'Incorrect input shape'})

if __name__ == '__main__':
         ngrok.set_auth_token('2jKqMzluXmiN6O7R43HlWyc0rO4_G3YnckFfQDgMDNKQG6rX')  # Replace with your ngrok auth token
         public_url = ngrok.connect(5000)
         print('Public URL:', public_url)
         app.run(port=5000)
# Out:
# Public URL: NgrokTunnel: "https://078e-35-229-79-214.ngrok-free.app" -> "http://localhost:5000"
#  * Serving Flask app '__main__'
#  * Debug mode: off
# INFO:werkzeug:WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# INFO:werkzeug:Press CTRL+C to quit
# INFO:werkzeug:127.0.0.1 - - [21/Jul/2024 19:10:37] "GET / HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [21/Jul/2024 19:10:37] "GET /static/Capture%20d'écran%202024-07-21%20160325.png HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [21/Jul/2024 19:10:37] "GET /static/Capture%20d'écran%202024-07-21%20160410.png HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [21/Jul/2024 19:10:37] "GET /static/xxxx.png HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [21/Jul/2024 19:10:38] "GET /favicon.ico HTTP/1.1" 404 -
# ...
